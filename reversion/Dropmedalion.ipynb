# %% [markdown]
# # Delete logical tables and physical locations

# %% [markdown]
# ## Widgets

# %%
# %python
dbutils.widgets.removeAll()

# %%
# %python
dbutils.widgets.text("catalogo","chocolate_sales")

# %% [markdown]
# ## Parameter

# %%
catalogo = dbutils.widgets.get("catalogo")

# %% [markdown]
# ## Bronze tables

# %%
# %sql
DROP TABLE IF EXISTS ${catalogo}.bronze.sales PURGE;
DROP TABLE IF EXISTS ${catalogo}.bronze.master_country PURGE;
DROP TABLE IF EXISTS ${catalogo}.bronze.master_product PURGE;
DROP TABLE IF EXISTS ${catalogo}.bronze.master_salesman PURGE;

# %% [markdown]
# ## Silver tables

# %%
# %sql
DROP TABLE IF EXISTS ${catalogo}.silver.sales_final PURGE;

# %% [markdown]
# ## Golden tables

# %%
# %sql
DROP TABLE IF EXISTS ${catalogo}.golden.sales_team_data PURGE;
DROP TABLE IF EXISTS ${catalogo}.golden.country_kpi PURGE;
DROP TABLE IF EXISTS ${catalogo}.golden.product_kpi PURGE;
DROP TABLE IF EXISTS ${catalogo}.golden.salesman_kpi PURGE;
